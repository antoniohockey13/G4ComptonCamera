# %% [markdown]
# # Validation 8 Results Camara Compton Simulation
#
# __Author: Antonio Gómez Carrera__

# %%
import ROOT
name = 'validation8.root'
file = ROOT.TFile(name)
# Out:
# Welcome to JupyROOT 6.30/02

# %% [markdown]
# Parameters used:
#
# ```
#     _world_width = 682*mm;
#     _world_height = 562*mm;
#     _world_depth = 354*mm;
#
#     _detector_size = 300*mm;
#     _detector_thickness = 150*um;
#     _detector_number = 2;
#
#     _detector_distance[1] = 100*mm;
#     _detector_distance[2] = 200*mm;
#
#     Particle_Energy = 70keV
#
# ```
#
# Beam of 500 000 000 particles
#
# Physic lists:
# * EmStandarPhysics_option4
# * DecayPhysics

# %% [markdown]
# ## Events

# %%
c = ROOT.TCanvas()
file.Hits.Draw("Event","","")
c.Draw()

# %% [markdown]
# ## Particle ID

# %%
c1 = ROOT.TCanvas()
#hPartID = file.Hits.Draw("ParticleID>>hID(14,9.5,23.5)","","")
file.Hits.Draw("ParticleID>>hID","","")
c1.Draw()

# %% [markdown]
# ## Process Name

# %%
c2 = ROOT.TCanvas()
c2.SetLogy()
file.Hits.Draw("ProcessName","","")
c2.Draw()

# %%
c2a = ROOT.TCanvas()
c2a.SetLogy()
file.Hits.Draw("ProcessName","ParticleID==22","")
c2a.Draw()

# %% [markdown]
# ## Position

# %%
c3 = ROOT.TCanvas()
c3.SetLogy()
file.Hits.Draw("X>>hX()", "", "")
hX = ROOT.gDirectory.Get("hX")
hX.GetXaxis().SetTitle('X/mm')
c3.Draw()

# %% [markdown]
# ## Compton Hits

# %%
c4 = ROOT.TCanvas()
c4.SetLogy()
file.ComptonHits.Draw("Event", "", "")
c4.Draw()

# %%
c4b = ROOT.TCanvas()
c4b.SetLogy()
file.Hits.Draw("Event", "ParticleID == 22", "")
c4b.Draw()

# %%
c5 = ROOT.TCanvas()
c5.SetLogy()
file.ComptonHits.Draw("cos(ComptonAngle)>>h(100,0,1)", "", "")
c5.Draw()

# %%
c6 = ROOT.TCanvas()
c6.SetLogy()
file.ComptonHits.Draw("100/((Time2-Time1)*0.3)>>hcos2(100,0,1)","", "")
hcos2 = ROOT.gDirectory.Get("hcos2")
hcos2.GetXaxis().SetTitle('cos Theta')
c6.Draw()

# %% [markdown]
# Compton efficienciy ($\epsilon$)
#
# $$
# \epsilon = \frac{\text{Compton events}}{\text{Total events}}= \frac{9745}{5e8}=1.9e-5
#
# $$

# %%
c6 = ROOT.TCanvas()
c6.SetLogy()
file.ComptonHits.Draw("(X2-X1)/sqrt((X2-X1)^2+(Y2-Y1)^2+(Z2-Z1)^2)>>hcos2(100,0,1)","", "")
hcos2 = ROOT.gDirectory.Get("hcos2")
hcos2.GetXaxis().SetTitle('cos Theta')
c6.Draw()
