# %% [markdown]
# # Crosscheck Biasing
#
# 1. bias_crosscheck.root
#
# ```
# Events = 5e6
# Cross section compton *10
# Cross section photoelectric *10
# ```
# 2. validation11.root
#
# 3. bias_crosscheck_2.root
#
# ```
# Events = 5e6
# Biasing --> file from GB01
# ```
# 4. bias_crosscheck_3.root
#
# ```
# Events = 5e6
# Non biased but processes added  by hand
# ```
# ```
# detector_number = 2
# detector_size = 300*mm
# detector_thickness = 150*um
# detector_position = 100, 200*mm
# ```

# %%
import ROOT
file = ROOT.TFile("validation11.root")
cross_check = ROOT.TFile("bias_crosscheck.root")
cross_check2 = ROOT.TFile("bias_crosscheck_2.root")
only_processes = ROOT.TFile("bias_crosscheck_3.root")
# Out:
# Welcome to JupyROOT 6.30/02

# %% [markdown]
# ## Particle ID

# %%
c1 = ROOT.TCanvas()
# Normalise histograms by number of events

file.Hits.Draw("ParticleID","","")

only_processes.Hits.SetLineColor(ROOT.kBlue)
only_processes.Hits.SetLineStyle(2)
only_processes.Hits.Draw("ParticleID","","same")

legend = ROOT.TLegend(0.3,0.75,0.5,0.9)
legend.AddEntry(file.Hits,"Non biased","l")
legend.AddEntry(only_processes.Hits,"Non biased process by hand","l")

legend.Draw()
c1.Draw()

# %%
# Compute ratio of particle ID 11 to particle ID 22
ratio = file.Hits.GetEntries("ParticleID==11")/file.Hits.GetEntries("ParticleID==22")
print("Ratio of electrons to photons in non biased data is: ", ratio)

processes_ratio = only_processes.Hits.GetEntries("ParticleID==11")/only_processes.Hits.GetEntries("ParticleID==22")
print("Ratio of electrons to photons in non biased data by hand is: ", processes_ratio)
# Out:
# Ratio of electrons to photons in non biased data is:  4.52
# Ratio of electrons to photons in non biased data by hand is:  5.9049548588895995

# %% [markdown]
# ## Process Name

# %%
c2 = ROOT.TCanvas()
c2.SetLogy()
file.Hits.Draw("ProcessName","","")
only_processes.Hits.SetLineColor(ROOT.kBlue)
only_processes.Hits.SetLineStyle(2)
only_processes.Hits.Draw("ProcessName","","same")
legend2 = ROOT.TLegend(0.6,0.75,0.8,0.9)
legend2.AddEntry(file.Hits,"Non biased","l")
legend2.AddEntry(only_processes.Hits,"Non biased process by hand","l")
legend2.Draw()
c2.Draw()

# %%
c2 = ROOT.TCanvas()
c2.SetLogy()
file.Hits.Draw("ProcessName","ParticleID == 22","")

only_processes.Hits.SetLineColor(ROOT.kBlue)
only_processes.Hits.SetLineStyle(2)
only_processes.Hits.Draw("ProcessName","ParticleID == 22","same")
legend2 = ROOT.TLegend(0.6,0.75,0.8,0.9)
legend2.AddEntry(file.Hits,"Non biased","l")
legend2.AddEntry(only_processes.Hits,"Non biased process by hand","l")
legend2.Draw()
c2.Draw()

# %% [markdown]
# ## Compton Hits, Compton Angle
# Hit in both detectors

# %%
c3 = ROOT.TCanvas()
c3.SetLogy()
file.ComptonHits.Draw("ComptonAngle","","")

only_processes.ComptonHits.SetLineColor(ROOT.kBlue)
only_processes.ComptonHits.SetLineStyle(2)
only_processes.ComptonHits.Draw("ComptonAngle","","")
legend3 = ROOT.TLegend(0.5,0.75,0.7,0.9)
legend3.AddEntry(file.ComptonHits,"Non biased","l")
legend3.AddEntry(only_processes.ComptonHits,"Non biased process by hand","l")
legend3.Draw()
c3.Draw()

# %%
c4 = ROOT.TCanvas()
only_processes.ComptonHits.Draw("ComptonAngle","","")
c4.Draw()
